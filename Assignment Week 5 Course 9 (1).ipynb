# %% [markdown]
# <h1 align=center><font size = 5>Clustering New York and Toronto Neighbourhoods together</font></h1>
#
#
# This Project clusters the neighbourhoods of two different cities, i.e., Toronto and New York together so that if a person wants to move from one city to another, he/she can choose the area to live in the new city from the same cluster as his/her current area so that they can get the similar venues and facilities nearby.

# %% [markdown]
# For this, we would need the Neighbourhood data for both the cities arranged in same way and then we will club the data together to apply clustering algorithm on the data.

# %% [markdown]
# Before we get the data and start exploring it, let's download all the dependencies that we will need.

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

import urllib.request

print('Libraries imported.')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-1.22.0               |     pyh9f0ad1d_0          63 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          97 KB
#
# The following NEW packages will be INSTALLED:
#
#   geographiclib      conda-forge/noarch::geographiclib-1.50-py_0
#   geopy              conda-forge/noarch::geopy-1.22.0-pyh9f0ad1d_0
#
#
#
# Downloading and Extracting Packages
# geopy-1.22.0         | 63 KB     | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Libraries imported.

# %% [markdown]
# ## 1. NEW YORK DATA.
#
# We will download and arrange the data one by one for both the cities in same format.
# First We will work to get New York Dataset.
#
# This dataset exists for free on the web. Feel free to try to find this dataset on your own, but here is the link to the dataset: https://geo.nyu.edu/catalog/nyu_2451_34572

# %%
# !wget -q -O 'newyork_data.json' https://cocl.us/new_york_dataset
print('Data downloaded!')
# Out:
# Data downloaded!

# %% [markdown]
# In the following cell, We will process the downloaded data for New York city and put it in a readable Dataframe which we can process further. Also it will filter the Manhattan area and map it. For our project, we have taken only Manhattan area.

# %%
with open('newyork_data.json') as json_data:
    newyork_data = json.load(json_data)

neighborhoods_data = newyork_data['features']

# define the dataframe columns
column_names = ['Borough', 'Neighbourhood', 'Latitude', 'Longitude'] 

# instantiate the dataframe
neighborhoods = pd.DataFrame(columns=column_names)


for data in neighborhoods_data:
    borough = neighborhood_name = data['properties']['borough'] 
    neighborhood_name = data['properties']['name']
        
    neighborhood_latlon = data['geometry']['coordinates']
    neighborhood_lat = neighborhood_latlon[1]
    neighborhood_lon = neighborhood_latlon[0]
    
    neighborhoods = neighborhoods.append({'Borough': borough,
                                          'Neighbourhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)
    

print('The dataframe has {} boroughs and {} neighbourhoods.'.format(
        len(neighborhoods['Borough'].unique()),
        neighborhoods.shape[0]
    )
)



manhattan_data = neighborhoods[neighborhoods['Borough'] == 'Manhattan'].reset_index(drop=True)
manhattan_data.head()


address = 'Manhattan, NY'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Manhattan are {}, {}.'.format(latitude, longitude))



# create map of Manhattan using latitude and longitude values
map_manhattan = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(manhattan_data['Latitude'], manhattan_data['Longitude'], manhattan_data['Neighbourhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_manhattan)  
    
map_manhattan
# Out:
# The dataframe has 5 boroughs and 306 neighbourhoods.
# The geograpical coordinate of Manhattan are 40.7896239, -73.9598939.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 2. TORONTO DATA.
#
# Now we will work on getting and arranging the Toronto Dataset in the same format with top 10 most common venues.
#
# This dataset exists for free on the web.
# https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M

# %%
html = ""

html = urllib.request.urlopen("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M").read().decode('utf-8')

df = pd.DataFrame(columns = ['Postal Code','Borough','Neighbourhood'])
rows = ['init1','init2','init3']
counter = 0


while True:
    #loop to fill the three items in the list named "rows"
    for i in range (0,3):
        LinkStart = html.find("<td>")
        if(LinkStart == -1):
            break
        html = html[LinkStart+4:]
        LinkEnd = html.find("<")
        rows[i] = html[:LinkEnd].strip()
    
    #if end of the html then exit the loop
    LinkStart = html.find("<td>")
    if(LinkStart == -1):
        break
    
    #if Neighbourhood is 'Not assigned' then set Borough as the Neighbourhood
    if(rows[2] == 'Not assigned'):
        rows[2] = rows[1]
        
    
    #if more than one Neighbourhood in one postal code, then put all the Neighbourhoods in the same row of the DataFrame
    if(counter != 0):    
        if(df.iloc[-1][0] == rows[0]):
            df.iloc[-1][0] = df.iloc[-1][0] + ', ' + rows[2]
        
        elif(rows[1] != 'Not assigned'):
            temp = pd.DataFrame({'Postal Code':rows[0],'Borough':rows[1],'Neighbourhood':rows[2]}, index=[0])
            df = pd.concat([df, temp])
    
    #if borough is not equal to "Not assigned", only then copy the row in the DataFrame.
    if(rows[1] != 'Not assigned'):
            temp = pd.DataFrame({'Postal Code':rows[0],'Borough':rows[1],'Neighbourhood':rows[2]}, index=[0])
            df = pd.concat([df, temp])
    
df.reset_index(drop=True)

# !wget -O Geospatial_Coordinates.csv https://cocl.us/Geospatial_data
    

latlong = pd.read_csv("Geospatial_Coordinates.csv")

df1 = df.merge(latlong, on='Postal Code')

address = 'Toronto, Canada'

geolocator = Nominatim(user_agent="ca_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geographical coordinate of Toronto are {}, {}.'.format(latitude, longitude))

# create map of Toronto using latitude and longitude values
map_Toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(df1['Latitude'], df1['Longitude'], df1['Borough'], df1['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_Toronto)  
    
map_Toronto

Toronto_Data = df1[df1['Borough'].str.contains('Toronto')].reset_index(drop=True)

# create map of Toronto using latitude and longitude values
map_Toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(Toronto_Data['Latitude'], Toronto_Data['Longitude'], Toronto_Data['Borough'], Toronto_Data['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_Toronto)  
    
map_Toronto

Toronto_Data_Filtered = Toronto_Data[['Borough','Neighbourhood','Latitude','Longitude']]
# Out:
# --2020-06-02 01:59:02--  https://cocl.us/Geospatial_data
# Resolving cocl.us (cocl.us)... 169.48.113.194, 158.85.108.86, 158.85.108.83
# Connecting to cocl.us (cocl.us)|169.48.113.194|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2020-06-02 01:59:05--  https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.box.com (ibm.box.com)... 107.152.27.197
# Connecting to ibm.box.com (ibm.box.com)|107.152.27.197|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2020-06-02 01:59:05--  https://ibm.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Reusing existing connection to ibm.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2020-06-02 01:59:05--  https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.ent.box.com (ibm.ent.box.com)... 107.152.29.201
# Connecting to ibm.ent.box.com (ibm.ent.box.com)|107.152.29.201|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://public.boxcloud.com/d/1/b1
# your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)

LIMIT = 100 # limit of number of venues returned by Foursquare API

radius = 500 # define radius
# Out:
# Your credentails:
# CLIENT_ID: UCPZ1OFL3V4RMZHIIUZZYZHWG0URVQVS4PBCTBZQVPOL325W
# CLIENT_SECRET:ZDSXDNIU1Y1KJMFVWE02OW0JAC5SU2KBQHUVU3WALNP0MM3L

# %%
Final_Data = Final_Data.reset_index(drop = True)

# %% [markdown]
# Creating following function to get the venues data for all the neighbourhoods. This is a generic function and will be used for both the cities.

# %%
Final_Data
# Out:
#              Borough                                      Neighbourhood  \
# 0          Manhattan                                        Marble Hill
# 1          Manhattan                                          Chinatown
# 2          Manhattan                                 Washington Heights
# 3          Manhattan                                             Inwood
# 4          Manhattan                                   Hamilton Heights
# 5          Manhattan                                     Manhattanville
# 6          Manhattan                                     Central Harlem
# 7          Manhattan                                        East Harlem
# 8          Manhattan                                    Upper East Side
# 9          Manhattan                                          Yorkville
# 10         Manhattan                                         Lenox Hill
# 11         Manhattan                                   Roosevelt Island
# 12         Manhattan                                    Upper West Side
# 13         Manhattan                                     Lincoln Square
# 14         Manhattan                                            Clinton
# 15         Manhattan                                            Midtown
# 16         Manhattan                                        Murray Hill
# 17         Manhattan                                            Chelsea
# 18         Manhattan                                  Greenwich Village
# 19         Manhattan                                       East Village
# 20         Manhattan                                    Lower East Side
# 21         Manhattan                                            Tribeca
# 22         Manhattan                                       Little Italy
# 23         Manhattan                                               Soho
# 24         Manhattan                                       West Village
# 25         Manhattan                                   Manhattan Valley
# 26         Manhattan                                Morningside Heights
# 27         Manhattan                                           Gramercy
# 28         Manhattan                                  Battery Park City
# 29         Manhattan                                 Financial District
# 30         Manhattan                                      Carnegie Hill
# 31         Manhattan                                               Noho
# 32         Manhattan                                       Civic Center
# 33         Manhattan                                      Midtown South
# 34         Manhattan                                       Sutton Place
# 35         Manhattan                                         Turtle Bay
# 36         Manhattan                                         Tudor City
# 37         Manhattan                                    Stuyvesant Town
# 38         Manhattan                                           Flatiron
# 39         Manhattan                                       Hudson Yards
# 40  Downtown Toronto                          Regent Park, Harbourfront
# 41  Downtown Toronto        Queen's Park, Ontario Provincial Government
# 42  Downtown Toronto                           Garden District, Ryerson
# 43  Downtown Toronto                                     St. James Town
# 44      East Toronto                                        The Beaches
# 45  Downtown Toronto                                        Berczy Park
# 46  Downtown Toronto                                 Central Bay Street
# 47  Downtown Toronto                                           Christie
# 48  Downtown Toronto                           Richmond, Adelaide, King
# 49      West Toronto                       Dufferin, Dovercourt Village
# 50  Downtown Toronto  Harbourfront East, Union Station, Toronto Islands
# 51      West Toronto                           Little Portugal, Trinity
# 52      East Toronto                       The Danforth West, Riverdale
# 53  Downtown Toronto           Toronto Dominion Centre, Design Exchange
# 54      West Toronto       Brockton, Parkdale Village, Exhibition Place
# 55      East Toronto                     India Bazaar, The Beaches West
# 56  Downtown Toronto                     Commerce Court, Victoria Hotel
# 57      East Toronto                                    Studio District
# 58   Central Toronto                                      Lawrence Park
# 59   Central Toronto                                           Roselawn
# 60   Central Toronto                                   Davisville North
# 61   Central Toronto  Forest Hill North &amp; West, Forest Hill Road...
# 62      West Toronto                      High Park, The Junction South
# 63   Central Toronto                 North Toronto West,  Lawrence Park
# 64   Central Toronto                The Annex, North Midtown, Yorkville
# 65      West Toronto                             Parkdale, Roncesvalles
# 66   Central Toronto                                         Davisville
# 67  Downtown Toronto                     University of Toronto, Harbord
# 68      West Toronto                                 Runnymede, Swansea
# 69   Central Toronto                        Moore Park, Summerhill East
# 70  Downtown Toronto          Kensington Market, Chinatown, Grange Park
#
# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighbourhood', 
                  'Neighbourhood Latitude', 
                  'Neighbourhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# Function created. Now calling the same for Manhatten data.

# %%
Final_venues = getNearbyVenues(names=Final_Data['Neighbourhood'],
                                   latitudes=Final_Data['Latitude'],
                                   longitudes=Final_Data['Longitude']
                                  )
# Out:
# Marble Hill
# Chinatown
# Washington Heights
# Inwood
# Hamilton Heights
# Manhattanville
# Central Harlem
# East Harlem
# Upper East Side
# Yorkville
# Lenox Hill
# Roosevelt Island
# Upper West Side
# Lincoln Square
# Clinton
# Midtown
# Murray Hill
# Chelsea
# Greenwich Village
# East Village
# Lower East Side
# Tribeca
# Little Italy
# Soho
# West Village
# Manhattan Valley
# Morningside Heights
# Gramercy
# Battery Park City
# Financial District
# Carnegie Hill
# Noho
# Civic Center
# Midtown South
# Sutton Place
# Turtle Bay
# Tudor City
# Stuyvesant Town
# Flatiron
# Hudson Yards
# Regent Park, Harbourfront
# Queen's Park, Ontario Provincial Government
# Garden District, Ryerson
# St. James Town
# The Beaches
# Berczy Park
# Central Bay Street
# Christie
# Richmond, Adelaide, King
# Dufferin, Dovercourt Village
# Harbourfront East, Union Station, Toronto Islands
# Little Portugal, Trinity
# The Danforth West, Riverdale
# Toronto Dominion Centre, Design Exchange
# Brockton, Parkdale Village, Exhibition Place
# India Bazaar, The Beaches West
# Commerce Court, Victoria Hotel
# Studio District
# Lawrence Park
# Roselawn
# Davisville North
# Forest Hill North &amp; West, Forest Hill Road Park
# High Park, The Junction South
# North Toronto West,  Lawrence Park
# The Annex, North Midtown, Yorkville
# Parkdale, Roncesvalles
# Davisville
# University of Toronto, Harbord
# Runnymede, Swansea
# Moore Park, Summerhill East
# Kensington Market, Chinatown, Grange Park
# Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park
# CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport
# Rosedale
# Stn A PO Boxes
# St. James Town, Cabbagetown
# First Canadian Place, Underground city
# Church and Wellesley
# Business reply mail Processing Centre, South Central Letter Processing Plant Toronto

# %%
Final_venues.groupby('Neighbourhood').count()

# one hot encoding
Final_onehot = pd.get_dummies(Final_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
Final_onehot['Neighbourhood'] = Final_venues['Neighbourhood'] 

# move neighborhood column to the first column
fixed_columns = [Final_onehot.columns[-1]] + list(Final_onehot.columns[:-1])
Final_onehot = Final_onehot[fixed_columns]

Final_onehot.head()

Final_grouped = Final_onehot.groupby('Neighbourhood').mean().reset_index()

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighbourhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighbourhood'] = Final_grouped['Neighbourhood']

for ind in np.arange(Final_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(Final_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                        Neighbourhood 1st Most Common Venue  \
# 0                                  Battery Park City                  Park
# 1                                        Berczy Park           Coffee Shop
# 2       Brockton, Parkdale Village, Exhibition Place                  Café
# 3  Business reply mail Processing Centre, South C...           Yoga Studio
# 4  CN Tower, King and Spadina, Railway Lands, Har...       Airport Service
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0           Coffee Shop                 Hotel                   Gym
# 1          Cocktail Bar                  Café           Cheese Shop
# 2           Coffee Shop        Breakfast Spot                Bakery
# 3  Gym / Fitness Center            Comic Shop      Recording Studio
# 4        Airport Lounge      Airport Terminal                 Plane
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0         Memorial Site                 Plaza             Wine Shop
# 1                   Pub              Beer Bar            Restaurant
# 2            Restaurant         Grocery Store                   Gym
# 3            Restaurant                  Park            Skate Park
# 4              Boutique      Sculpture Garden           Coffee Shop
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0         Boat or Ferry          Gourmet Shop             Food Court
# 1                Bakery    Seafood Restaurant         Breakfast Spot
# 2          Climbing Gym    Italian Restaurant  Performing Arts Venue
# 3         Burrito Place        Farmers Market   Fast Food Restaurant
# 4       Harbor / Marina   Rental Car Location          Boat or Ferry

# %% [markdown]
# ## 3. Cluster combined Neighborhoods data
#
# Cluster the neighbourhoods data using k-means clustering

# %%
print('There are {} uniques categories.'.format(len(Final_venues['Venue Category'].unique())))
# Out:
# There are 376 uniques categories.

# %%
Final_merged
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-3065aab0aa0d> in <module>
# ----> 1 Final_merged
#
# NameError: name 'Final_merged' is not defined

# %%
num_top_venues = 5

for hood in Final_grouped['Neighbourhood']:
    print("----"+hood+"----")
    temp = Final_grouped[Final_grouped['Neighbourhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Battery Park City----
#            venue  freq
# 0           Park  0.12
# 1    Coffee Shop  0.08
# 2          Hotel  0.06
# 3            Gym  0.05
# 4  Memorial Site  0.05
#
#
# ----Berczy Park----
#                 venue  freq
# 0         Coffee Shop  0.07
# 1        Cocktail Bar  0.05
# 2         Cheese Shop  0.03
# 3  Seafood Restaurant  0.03
# 4              Bakery  0.03
#
#
# ----Brockton, Parkdale Village, Exhibition Place----
#             venue  freq
# 0            Café  0.13
# 1  Breakfast Spot  0.09
# 2     Coffee Shop  0.09
# 3             Bar  0.04
# 4   Grocery Store  0.04
#
#
# ----Business reply mail Processing Centre, South Central Letter Processing Plant Toronto----
#                   venue  freq
# 0           Yoga Studio  0.06
# 1            Restaurant  0.06
# 2         Burrito Place  0.06
# 3  Fast Food Restaurant  0.06
# 4                Garden  0.06
#
#
# ----CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport----
#                  venue  freq
# 0      Airport Service  0.18
# 1       Airport Lounge  0.12
# 2     Airport Terminal  0.12
# 3     Sculpture Garden  0.06
# 4  Rental Car Location  0.06
#
#
# ----Carnegie Hill----
#          venue  freq
# 0  Coffee Shop  0.10
# 1  Pizza Place  0.05
# 2         Café  0.05
# 3          Gym  0.04
# 4    Bookstore  0.04
#
#
# ----Central Bay Street----
#                  venue  freq
# 0          Coffee Shop  0.17
# 1   Italian Restaurant  0.06
# 2                 Café  0.06
# 3       Sandwich Place  0.05
# 4  Japanese Restaurant  0.05
#
#
# ----Central Harlem----
#                 venue  freq
# 0  African Restaurant  0.07
# 1  Seafood Restaurant  0.05
# 2   French Restaurant  0.05
# 3      Cosmetics Shop  0.05
# 4                 Bar  0.05
#
#
# ----Chelsea----
#             venue  freq
# 0     Art Gallery  0.10
# 1     Coffee Shop  0.07
# 2            Café  0.04
# 3          Bakery  0.03
# 4  Ice Cream Shop  0.03
#
#
# ----Chinatown----
#                  venue  freq
# 0   Chinese Restaurant  0.06
# 1               Bakery  0.05
# 2      Bubble Tea Shop  0.04
# 3         Cocktail Bar  0.04
# 4  American Restaurant  0.03
#
#
# ----Christie----
#            venue  freq
# 0  Grocery Store  0.25
# 1           Café  0.19
# 2           Park  0.12
# 3      Nightclub  0.06
# 4    Candy Store  0.06
#
#
# ----Church and Wellesley----
#                  venue  freq
# 0          Coffee Shop  0.07
# 1     Sushi Restaurant  0.06
# 2  Japanese Restaurant  0.06
# 3              Gay Bar  0.04
# 4           Restaurant  0.04
#
#
# ----Civic Center----
#                  venue  freq
# 0          Coffee Shop  0.06
# 1    French Restaurant  0.05
# 2  American Restaurant  0.05
# 3                 Park  0.04
# 4         Cocktail Bar  0.04
#
#
# ----Clinton----
#                   venue  freq
# 0               Theater  0.08
# 1  Gym / Fitness Center  0.05
# 2           Coffee Shop  0.05
# 3                   Gym  0.04
# 4                 Hotel  0.04
#
#
# ----Commerce Court, Victoria Hotel----
#                  venue  freq
# 0          Coffee Shop  0.11
# 1                 Café  0.07
# 2           Restaurant  0.07
# 3                Hotel  0.05
# 4  American Restaurant  0.04
#
#
# ----Davisville----
#                 venue  freq
# 0         Pizza Place  0.11
# 1      Sandwich Place  0.09
# 2        Dessert Shop  0.09
# 3                Café  0.06
# 4  Italian Restaurant  0.06
#
#
# ----Davisville North----
#                   venue  freq
# 0                  Park  0.12
# 1           Pizza Place  0.12
# 2     Food & Drink Shop  0.12
# 3  Gym / Fitness Center  0.12
# 4        Sandwich Place  0.12
#
#
# ----Dufferin, Dovercourt Village----
#            venue  freq
# 0         Bakery  0.12
# 1       Pharmacy  0.12
# 2  Grocery Store  0.06
# 3    Music Venue  0.06
# 4           Bank  0.06
#
#
# ----East Harlem----
#                 venue  freq
# 0  Mexican Restaurant  0.11
# 1              Bakery  0.09
# 2     Thai Restaurant  0.07
# 3       Deli / Bodega  0.07
# 4                 Spa  0.04
#
#
# ----East Village----
#                 venue  freq
# 0  Mexican Restaurant  0.05
# 1        Cocktail Bar  0.05
# 2         Coffee Shop  0.04
# 3                 Bar  0.04
# 4         Pizza Place  0.04
#
#
# ----Financial District----
#                  venue  freq
# 0          Coffee Shop  0.08
# 1  American Restaurant  0.05
# 2          Pizza Place  0.05
# 3                 Café  0.04
# 4                Hotel  0.04
#
#
# ----First Canadian Place, Underground city----
#                  venue  freq
# 0          Coffee Shop  0.10
# 1                 Café  0.08
# 2                Hotel  0.04
# 3  Japanese Restaurant  0.04
# 4           Restaurant  0.04
#
#
# ----Flatiron----
#                       venue  freq
# 0      Gym / Fitness Center  0.08
# 1                      Café  0.04
# 2        Italian Restaurant  0.04
# 3  Mediterranean Restaurant  0.04
# 4               Yoga Studio  0.03
#
#
# ----Forest Hill North &amp; West, Forest Hill Road Park----
#                 venue  freq
# 0  Mexican Restaurant  0.25
# 1    Sushi Restaurant  0.25
# 2               Trail  0.25
# 3       Jewelry Store  0.25
# 4   Accessories Store  0.00
#
#
# ----Garden District, Ryerson----
#                  venue  freq
# 0       Clothing Store  0.09
# 1          Coffee Shop  0.08
# 2       Cosmetics Shop  0.03
# 3      Bubble Tea Shop  0.03
# 4  Japanese Restaurant  0.03
#
#
# ----Gramercy----
#          venue  freq
# 0   Bagel Shop  0.06
# 1          Bar  0.05
# 2  Pizza Place  0.05
# 3  Coffee Shop  0.05
# 4   Playground  0.04
#
#
# ----Greenwich Village----
#                 venue  freq
# 0  Italian Restaurant  0.08
# 1                Café  0.05
# 2    Sushi Restaurant  0.04
# 3                 Gym  0.03
# 4         Pizza Place  0.03
#
#
# ----Hamilton Heights----
#                 venue  freq
# 0         Pizza Place  0.10
# 1         Coffee Shop  0.07
# 2                Café  0.07
# 3       Deli / Bodega  0.05
# 4  Mexican Restaurant  0.05
#
#
# ----Harbourfront East, Union Station, Toronto Islands----
#                  venue  freq
# 0          Coffee Shop  0.13
# 1             Aquarium  0.05
# 2                 Café  0.04
# 3                Hotel  0.04
# 4  Fried Chicken Joint  0.03
#
#
# ----High Park, The Junction South----
#                 venue  freq
# 0                Park  0.08
# 1  Mexican Restaurant  0.08
# 2     Thai Restaurant  0.08
# 3                Café  0.08
# 4           Gastropub  0.04
#
#
# ----Hudson Yards----
#                   venue  freq
# 0    Italian Restaurant  0.07
# 1  Gym / Fitness Center  0.07
# 2                 Hotel  0.05
# 3   American Restaurant  0.04
# 4            Restaurant  0.04
#
#
# ----India Bazaar, The Beaches West----
#                   venue  freq
# 0  Fast Food Restaurant  0.10
# 1                  Park  0.10
# 2        Ice Cream Shop  0.05
# 3             Pet Store  0.05
# 4               Brewery  0.05
#
#
# ----Inwood----
#                 venue  freq
# 0  Mexican Restaurant  0.07
# 1          Restaurant  0.05
# 2                Café  0.05
# 3              Lounge  0.05
# 4  Chinese Restaurant  0.04
#
#
# ----Kensington Market, Chinatown, Grange Park----
#                    venue  freq
# 0                   Café  0.08
# 1            Coffee Shop  0.07
# 2  Vietnamese Restaurant  0.05
# 3                 Bakery  0.05
# 4     Mexican Restaurant  0.05
#
#
# ----Lawrence Park----
#                venue  freq
# 0               Park  0.33
# 1        Swim School  0.33
# 2           Bus Line  0.33
# 3  Accessories Store  0.00
# 4          Newsstand  0.00
#
#
# ----Lenox Hill----
#                 venue  freq
# 0         Coffee Shop  0.06
# 1         Pizza Place  0.05
# 2  Italian Restaurant  0.05
# 3                Café  0.04
# 4        Cocktail Bar  0.04
#
#
# ----Lincoln Square----
#                    venue  freq
# 0                   Café  0.05
# 1     Italian Restaurant  0.05
# 2                  Plaza  0.05
# 3  Performing Arts Venue  0.04
# 4           Concert Hall  0.04
#
#
# ----Little Italy----
#                       venue  freq
# 0        Chinese Restaurant  0.04
# 1  Mediterranean Restaurant  0.04
# 2               Pizza Place  0.04
# 3        Italian Restaurant  0.04
# 4            Ice Cream Shop  0.04
#
#
# ----Little Portugal, Trinity----
#               venue  freq
# 0               Bar  0.11
# 1  Asian Restaurant  0.07
# 2              Café  0.05
# 3       Coffee Shop  0.05
# 4        Restaurant  0.05
#
#
# ----Lower East Side----
#                 venue  freq
# 0  Chinese Restaurant  0.08
# 1                Park  0.04
# 2         Art Gallery  0.04
# 3                Café  0.04
# 4              Bakery  0.04
#
#
# ----Manhattan Valley----
#                 venue  freq
# 0         Coffee Shop  0.10
# 1         Yoga Studio  0.05
# 2                 Bar  0.05
# 3  Mexican Restaurant  0.05
# 4         Pizza Place  0.05
#
#
# ----Manhattanville----
#                 venue  freq
# 0         Coffee Shop  0.09
# 1  Seafood Restaurant  0.07
# 2  Italian Restaurant  0.05
# 3  Mexican Restaurant  0.05
# 4                Park  0.05
#
#
# ----Marble Hill----
#             venue  freq
# 0  Sandwich Place  0.12
# 1             Gym  0.08
# 2     Coffee Shop  0.08
# 3           Diner  0.04
# 4      Steakhouse  0.04
#
#
# ----Midtown----
#                  venue  freq
# 0          Coffee Shop  0.06
# 1                Hotel  0.05
# 2              Theater  0.04
# 3               Bakery  0.04
# 4  Japanese Restaurant  0.03
#
#
# ----Midtown South----
#                  venue  freq
# 0    Korean Restaurant  0.14
# 1                Hotel  0.05
# 2         Dessert Shop  0.04
# 3  American Restaurant  0.04
# 4         Burger Joint  0.04
#
#
# ----Moore Park, Summerhill East----
#                venue  freq
# 0               Park  0.33
# 1              Trail  0.33
# 2         Restaurant  0.33
# 3  Accessories Store  0.00
# 4          Newsstand  0.00
#
#
# ----Morningside Heights----
#                  venue  freq
# 0                 Park  0.10
# 1  American Restaurant  0.08
# 2          Coffee Shop  0.08
# 3            Bookstore  0.08
# 4        Deli / Bodega  0.05
#
#
# ----Murray Hill----
#                  venue  freq
# 0       Sandwich Place  0.05
# 1          Pizza Place  0.04
# 2  Japanese Restaurant  0.04
# 3                Hotel  0.04
# 4          Coffee Shop  0.04
#
#
# ----Noho----
#                  venue  freq
# 0          Coffee Shop  0.06
# 1          Pizza Place  0.05
# 2   Italian Restaurant  0.05
# 3        Grocery Store  0.04
# 4  Japanese Restaurant  0.04
#
#
# ----North Toronto West,  Lawrence Park----
#                  venue  freq
# 0       Clothing Store  0.09
# 1          Coffee Shop  0.09
# 2          Yoga Studio  0.05
# 3            Pet Store  0.05
# 4  Sporting Goods Shop  0.05
#
#
# ----Parkdale, Roncesvalles----
#             venue  freq
# 0  Breakfast Spot  0.14
# 1       Gift Shop  0.14
# 2      Restaurant  0.07
# 3       Bookstore  0.07
# 4             Bar  0.07
#
#
# ----Queen's Park, Ontario Provincial Government----
#               venue  freq
# 0       Coffee Shop  0.22
# 1  Sushi Restaurant  0.06
# 2       Yoga Studio  0.03
# 3        Restaurant  0.03
# 4               Bar  0.03
#
#
# ----Regent Park, Harbourfront----
#          venue  freq
# 0  Coffee Shop  0.18
# 1          Pub  0.07
# 2       Bakery  0.07
# 3         Park  0.07
# 4         Café  0.04
#
#
# ----Richmond, Adelaide, King----
#            venue  freq
# 0    Coffee Shop  0.11
# 1           Café  0.05
# 2     Restaurant  0.04
# 3          Hotel  0.03
# 4  Deli / Bodega  0.03
#
#
# ----Roosevelt Island----
#             venue  freq
# 0            Park  0.07
# 1   Indie Theater  0.03
# 2  Scenic Lookout  0.03
# 3             Gym  0.03
# 4  Baseball Field  0.03
#
#
# ----Rosedale----
#                venue  freq
# 0               Park  0.50
# 1         Playground  0.25
# 2              Trail  0.25
# 3  Accessories Store  0.00
# 4          Newsstand  0.00
#
#
# ----Roselawn----
#                      venue  freq
# 0                   Garden   0.5
# 1             Home Service   0.5
# 2  New American Restaurant   0.0
# 3     Other Great Outdoors   0.0
# 4          Organic Grocery   0.0
#
#
# ----Runnymede, Swansea----
#               venue  freq
# 0       Coffee Shop  0.08
# 1              Café  0.08
# 2  Sushi Restaurant  0.06
# 3       Pizza Place  0.06
# 4               Pub  0.06
#
#
# ----Soho----
#                       venue  freq
# 0        Italian Restaurant  0.11
# 1            Sandwich Place  0.05
# 2  Mediterranean Restaurant  0.05
# 3            Ice Cream Shop  0.04
# 4                    Bakery  0.04
#
#
# ----St. James Town----
#           venue  freq
# 0          Café  0.06
# 1   Coffee Shop  0.06
# 2  Cocktail Bar  0.05
# 3    Restaurant  0.04
# 4     Gastropub  0.04
#
#
# ----St. James Town, Cabbagetown----
#          venue  freq
# 0  Coffee Shop  0.08
# 1       Bakery  0.06
# 2   Restaurant  0.06
# 3  Pizza Place  0.06
# 4         Café  0.06
#
#
# ----Stn A PO Boxes----
#                 venue  freq
# 0         Coffee Shop  0.10
# 1                Café  0.04
# 2          Restaurant  0.03
# 3  Seafood Restaurant  0.03
# 4            Beer Bar  0.03
#
#
# ----Studio District----
#          venue  freq
# 0         Café  0.10
# 1  Coffee Shop  0.07
# 2       Bakery  0.05
# 3      Brewery  0.05
# 4    Gastropub  0.05
#
#
# ----Stuyvesant Town----
#                   venue  freq
# 0                  Park  0.14
# 1  Gym / Fitness Center  0.07
# 2                Bistro  0.07
# 3       Harbor / Marina  0.07
# 4          Cocktail Bar  0.07
#
#
# ----Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park----
#                  venue  freq
# 0                  Pub  0.12
# 1          Coffee Shop  0.12
# 2   Light Rail Station  0.06
# 3  American Restaurant  0.06
# 4     Sushi Restaurant  0.06
#
#
# ----Sutton Place----
#                   venue  freq
# 0           Coffee Shop  0.05
# 1  Gym / Fitness Center  0.04
# 2                  Park  0.04
# 3    Italian Restaurant  0.04
# 4            Bagel Shop  0.03
#
#
# ----The Annex, North Midtown, Yorkville----
#                venue  freq
# 0     Sandwich Place  0.14
# 1               Café  0.14
# 2        Coffee Shop  0.09
# 3  Indian Restaurant  0.05
# 4   Asian Restaurant  0.05
#
#
# ----The Beaches----
#                venue  freq
# 0                Pub  0.25
# 1              Trail  0.25
# 2       Neighborhood  0.25
# 3  Health Food Store  0.25
# 4          Nightclub  0.00
#
#
# ----The Danforth West, Riverdale----
#                 venue  freq
# 0    Greek Restaurant  0.21
# 1  Italian Restaurant  0.07
# 2         Coffee Shop  0.07
# 3      Ice Cream Shop  0.05
# 4          Restaurant  0.05
#
#
# ----Toronto Dominion Centre, Design Exchange----
#          venue  freq
# 0  Coffee Shop  0.10
# 1         Café  0.06
# 2        Hotel  0.06
# 3   Restaurant  0.04
# 4  Salad Place  0.03
#
#
# ----Tribeca----
#                  venue  freq
# 0   Italian Restaurant  0.06
# 1                 Park  0.06
# 2  American Restaurant  0.05
# 3               Bakery  0.04
# 4                  Spa  0.04
#
#
# ----Tudor City----
#                 venue  freq
# 0                Café  0.07
# 1                Park  0.07
# 2  Mexican Restaurant  0.05
# 3       Deli / Bodega  0.04
# 4    Sushi Restaurant  0.04
#
#
# ----Turtle Bay----
#               venue  freq
# 0       Coffee Shop  0.04
# 1  Sushi Restaurant  0.04
# 2              Café  0.04
# 3     Deli / Bodega  0.04
# 4              Park  0.04
#
#
# ----University of Toronto, Harbord----
#         venue  freq
# 0        Café  0.14
# 1   Bookstore  0.09
# 2      Bakery  0.06
# 3  Restaurant  0.06
# 4         Bar  0.06
#
#
# ----Upper East Side----
#                   venue  freq
# 0    Italian Restaurant  0.08
# 1                Bakery  0.06
# 2           Coffee Shop  0.04
# 3  Gym / Fitness Center  0.04
# 4           Yoga Studio  0.03
#
#
# ----Upper West Side----
#                 venue  freq
# 0                 Bar  0.05
# 1              Bakery  0.04
# 2  Italian Restaurant  0.04
# 3            Wine Bar  0.04
# 4        Dessert Shop  0.04
#
#
# ----Washington Heights----
#                 venue  freq
# 0                Café  0.06
# 1              Bakery  0.05
# 2   Mobile Phone Shop  0.03
# 3  Chinese Restaurant  0.03
# 4       Grocery Store  0.03
#
#
# ----West Village----
#                  venue  freq
# 0   Italian Restaurant  0.07
# 1             Wine Bar  0.05
# 2                 Park  0.04
# 3  American Restaurant  0.04
# 4         Cocktail Bar  0.04
#
#
# ----Yorkville----
#                 venue  freq
# 0         Coffee Shop  0.07
# 1                 Gym  0.06
# 2  Italian Restaurant  0.06
# 3                 Bar  0.05
# 4    Sushi Restaurant  0.04

# %%
#Final_merged = Final_merged.reset_index()

# set number of clusters
kclusters = 5

Final_grouped_clustering = Final_grouped.drop('Neighbourhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(Final_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]

# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

Final_merged = Final_Data

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
Final_merged = Final_merged.join(neighborhoods_venues_sorted.set_index('Neighbourhood'), on='Neighbourhood')

Final_merged.head() # check the last columns!
# Out:
#      Borough       Neighbourhood   Latitude  Longitude  Cluster Labels  \
# 0  Manhattan         Marble Hill  40.876551 -73.910660               3
# 1  Manhattan           Chinatown  40.715618 -73.994279               3
# 2  Manhattan  Washington Heights  40.851903 -73.936900               3
# 3  Manhattan              Inwood  40.867684 -73.921210               3
# 4  Manhattan    Hamilton Heights  40.823604 -73.949688               3
#
#   1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 0        Sandwich Place           Coffee Shop                   Gym
# 1    Chinese Restaurant                Bakery          Cocktail Bar
# 2                  Café                Bakery         Grocery Store
# 3    Mexican Restaurant                Lounge            Restaurant
# 4           Pizza Place                  Café           Coffee Shop
#
#   4th Most Common Venue  5th Most Common Venue 6th Most Common Venue  \
# 0           Yoga Studio     Miscellaneous Shop            Steakhouse
# 1       Bubble Tea Shop  Vietnamese Restaurant    Salon / Barbershop
# 2    Chinese Restaurant      Mobile Phone Shop                   Gym
# 3                  Café                 Bakery         Deli / Bodega
# 4    Mexican Restaurant          Deli / Bodega           Yoga Studio
#
#   7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 0         Shopping Mall       Supplement Shop    Seafood Restaurant
# 1           Coffee Shop        Ice Cream Shop          Optical Shop
# 2    Mexican Restaurant           Supermarket        Sandwich Place
# 3    Frozen Yogurt Shop    Chinese Restaurant  Caribbean Restaurant
# 4  Caribbean Restaurant      Sushi Restaurant                Bakery
#
#   10th Most Common Venue
# 0             Donut Shop
# 1    American Restaurant
# 2                   Bank
# 3    American Restaurant
# 4                 School

# %%
address = 'Rochester, New York'

geolocator = Nominatim(user_agent="ca_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
#print('The geographical coordinate of Toronto are {}, {}.'.format(latitude, longitude))


# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=7)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(Final_merged['Latitude'], Final_merged['Longitude'], Final_merged['Neighbourhood'], Final_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
Final_merged
# Out:
#              Borough                                      Neighbourhood  \
# 0          Manhattan                                        Marble Hill
# 1          Manhattan                                          Chinatown
# 2          Manhattan                                 Washington Heights
# 3          Manhattan                                             Inwood
# 4          Manhattan                                   Hamilton Heights
# 5          Manhattan                                     Manhattanville
# 6          Manhattan                                     Central Harlem
# 7          Manhattan                                        East Harlem
# 8          Manhattan                                    Upper East Side
# 9          Manhattan                                          Yorkville
# 10         Manhattan                                         Lenox Hill
# 11         Manhattan                                   Roosevelt Island
# 12         Manhattan                                    Upper West Side
# 13         Manhattan                                     Lincoln Square
# 14         Manhattan                                            Clinton
# 15         Manhattan                                            Midtown
# 16         Manhattan                                        Murray Hill
# 17         Manhattan                                            Chelsea
# 18         Manhattan                                  Greenwich Village
# 19         Manhattan                                       East Village
# 20         Manhattan                                    Lower East Side
# 21         Manhattan                                            Tribeca
# 22         Manhattan                                       Little Italy
# 23         Manhattan                                               Soho
# 24         Manhattan                                       West Village
# 25         Manhattan                                   Manhattan Valley
# 26         Manhattan                                Morningside Heights
# 27         Manhattan                                           Gramercy
# 28         Manhattan                                  Battery Park City
# 29         Manhattan                                 Financial District
# 30         Manhattan                                      Carnegie Hill
# 31         Manhattan                                               Noho
# 32         Manhattan                                       Civic Center
# 33         Manhattan                                      Midtown South
# 34         Manhattan                                       Sutton Place
# 35         Manhattan                                         Turtle Bay
# 36         Manhattan                                         Tudor City
# 37         Manhattan                                    Stuyvesant Town
# 38         Manhattan                                           Flatiron
# 39         Manhattan                                       Hudson Yards
# 40  Downtown Toronto                          Regent Park, Harbourfront
# 41  Downtown Toronto        Queen's Park, Ontario Provincial Government
# 42  Downtown Toronto                           Garden District, Ryerson
# 43  Downtown Toronto                                     St. James Town
# 44      East Toronto                                        The Beaches
# 45  Downtown Toronto                                        Berczy Park
# 46  Downtown Toronto                                 Central Bay Street
# 47  Downtown Toronto                                           Christie
# 48  Downtown Toronto                           Richmond, Adelaide, King
# 49      West Toronto                       Dufferin, Dovercourt Village
# 50  Downtown Toronto  Harbourfront East, Union Station, Toronto Islands
# 51      West Toronto                           Little Portugal, Trinity
# 52      East Toronto                       The Danforth West, Riverdale
# 53  Downtown Toronto           Toronto Dominion Centre, Design Exchange
# 54      West Toronto       Brockton, Parkdale Village, Exhibition Place
# 55      East Toronto                     India Bazaar, The Beaches West
# 56  Downtown Toronto                     Commerce Court, Victoria Hotel
# 57      East Toronto                                    Studio District
# 58   Central Toronto                                      Lawrence Park
# 59   Central Toronto                                           Roselawn
# 60   Central Toronto                                   Davisville North
# 61   Central Toronto  Forest Hill North &amp; West, Forest Hill Road...
# 62      West Toronto                      High Park, The Junction South
# 63   Central Toronto                 North Toronto West,  Lawrence Park
# 64   Central Toronto                The Annex, North Midtown, Yorkville
# 65      West Toronto                             Parkdale, Roncesvalles
# 66   Central Toronto                                         Davisville
# 67  Downtown Toronto                     University of Toronto, Harbord
# 68      West Toronto                                 Runnymede, Swansea
# 69   Central Toronto                        Moore Park, Summerhill East
# 70  Downtown Toronto          Kensington Market, Chinatown, Grange Park
# 71   Central Toronto  Summerhill West, Rathnelly, South Hill, Forest...
# 72  Downtown Toronto  CN Tower, King and Spadina, Railway Lands, Har...
# 73  Downtown Toronto                                           Rosedale
# 74  Downtown Toronto                                     Stn A PO Boxes
# 75  Downtown Toronto                        St. James Town, Cabbagetown
# 76  Downtown Toronto             First Canadian Place, Underground city
# 77  Downtown Toronto                               Church and Wellesley
# 78      East Toronto  Business reply mail Processing Centre, South C...
#
#      Latitude  Longitude  Cluster Labels 1st Most Common Venue  \
# 0   40.876551 -73.910660               3        Sandwich Place
# 1   40.715618 -73.994279               3    Chinese Restaurant
# 2   40.851903 -73.936900               3                  Café
# 3   40.867684 -73.921210               3    Mexican Restaurant
# 4   40.823604 -73.949688               3           Pizza Place
# 5   40.816934 -73.957385               3           Coffee Shop
# 6   40.815976 -73.943211               3    African Restaurant
# 7   40.792249 -73.944182               3    Mexican Restaurant
# 8   40.775639 -73.960508               3    Italian Restaurant
# 9   40.775930 -73.947118               3           Coffee Shop
# 10  40.768113 -73.958860               3           Coffee Shop
# 11  40.762160 -73.949168               0                  Park
# 12  40.787658 -73.977059               3                   Bar
# 13  40.773529 -73.985338               3                 Plaza
# 14  40.759101 -73.996119               3               Theater
# 15  40.754691 -73.981669               3           Coffee Shop
# 16  40.748303 -73.978332               3        Sandwich Place
# 17  40.744035 -74.003116               3           Art Gallery
# 18  40.726933 -73.999914               3    Italian Restaurant
# 3                     Lounge                Restaurant
# 4                       Café               Coffee Shop
# 5         Seafood Restaurant                  Bus Stop
# 6        American Restaurant            Cosmetics Shop
# 7                     Bakery           Thai Restaurant
# 8                     Bakery      Gym / Fitness Center
# 9         Italian Restaurant                       Gym
# 10        Italian Restaurant               Pizza Place
# 11                Playground              Liquor Store
# 12        Italian Restaurant                    Bakery
# 13                      Café        Italian Restaurant
# 14      Gym / Fitness Center               Coffee Shop
# 15                     Hotel                    Bakery
# 16      Gym / Fitness Center               Pizza Place
# 17               Coffee Shop                      Café
# 18                      Café          Sushi Restaurant
# 19        Mexican Restaurant               Pizza Place
# 20                      Park               Art Gallery
# 21                      Park       American Restaurant
# 22                       Spa        Italian Restaurant
# 23            Sandwich Place  Mediterranean Restaurant
# 24                  Wine Bar               Pizza Place
# 25               Yoga Studio        Mexican Restaurant
# 26       American Restaurant                 Bookstore
# 27               Pizza Place               Coffee Shop
# 28               Coffee Shop                     Hotel
# 29               Pizza Place       American Restaurant
# 30               Pizza Place                      Café
# 31        Italian Restaurant               Pizza Place
# 32       American Restaurant         French Restaurant
# 33                     Hotel       American Restaurant
# 34        Italian Restaurant                      Park
# 35                      Park                      Café
# 36                      Park        Mexican Restaurant
# 37                Playground                  Heliport
# 38  Mediterranean Restaurant        Italian Restaurant
# 39      Gym / Fitness Center                     Hotel
# 40                    Bakery                      Park
# 41          Sushi Restaurant               Yoga Studio
# 42               Coffee Shop           Bubble Tea Shop
# 43               Coffee Shop              Cocktail Bar
# 44                     Trail         Health Food Store
# 45              Cocktail Bar                      Café
# 46        Italian Restaurant                      Café
# 47                      Café                      Park
# 48                      Café                Restaurant
# 49                    Bakery                      Pool
# 50                  Aquarium                      Café
# 51          Asian Restaurant                Restaurant
# 52        Italian Restaurant               Coffee Shop
# 53                     Hotel                      Café
# 54               Coffee Shop            Breakfast Spot
# 55      Fast Food Restaurant         Fish & Chips Shop
# 56                      Café                Restaurant
# 57               Coffee Shop                 Gastropub
# 58                      Park               Swim School
# 59                    Garden               Yoga Studio
# 60            Breakfast Spot               Pizza Place
# 61          Sushi Restaurant                     Trail
# 62                      Park           Thai Restaurant
# 63            Clothing Store               Yoga Studio
# 64                      Café               Coffee Shop
# 65            Breakfast Spot                   Dog Run
# 66            Sandwich Place              Dessert Shop
# 67                 Bookstore       Japanese Restaurant
# 68                      Café        Italian Restaurant
# 69                     Trail                Restaurant
# 70               Coffee Shop     Vietnamese Restaurant
# 71                       Pub               Pizza Place
# 72            Airport Lounge          Airport Terminal
# 73                Playground                     Trail
# 74                      Café        Italian Restaurant
# 75                    Bakery               Pizza Place
# 76                      Café       Japanese Restaurant
# 77          Sushi Restaurant       Japanese Restaurant
# 78      Gym / Fitness Center                Comic Shop
#
#             4th Most Common Venue                     5th Most Common Venue  \
# 0                     Yoga Studio                        Miscellaneous Shop
# 1                 Bubble Tea Shop                     Vietnamese Restaurant
# 2              Chinese Restaurant                         Mobile Phone Shop
# 3                            Café                                    Bakery
# 4              Mexican Restaurant                             Deli / Bodega
# 5              Italian Restaurant                        Mexican Restaurant
# 6              Chinese Restaurant                         French Restaurant
# 7                   Deli / Bodega                 Latin American Restaurant
# 8                     Coffee Shop                                 Juice Bar
# 9                             Bar                             Deli / Bodega
# 10               Sushi Restaurant                              Cocktail Bar
# 11            Japanese Restaurant  Residential Building (Apartment / Condo)
# 12                       Wine Bar                              Dessert Shop
# 13          Performing Arts Venue                              Concert Hall
# 14                          Hotel                        Italian Restaurant
# 15                        Theater                       Japanese Restaurant
# 16                    Coffee Shop                                     Hotel
# 17            American Restaurant                            Ice Cream Shop
# 18                    Pizza Place                                       Gym
# 19                            Bar                               Coffee Shop
# 20                   Cocktail Bar                                    Bakery
# 21                         Bakery                                  Wine Bar
# 22                Bubble Tea Shop                                    Bakery
# 23                    Coffee Shop                                    Bakery
# 24        New American Restaurant                                    Bakery
# 25                    Pizza Place                                       Bar
# 26                    Coffee Shop                             Deli / Bodega
# 27                            Bar                        Mexican Restaurant
# 28                            Gym                             Memorial Site
# 29                           Café                                     Hotel
# 30                    Yoga Studio                                 Wine Shop
# 31                 Sandwich Place                             Grocery Store
# 32                   Cocktail Bar                                     Hotel
# 33                   Dessert Shop                              Burger Joint
# 34           Gym / Fitness Center                                     Hotel
# 35                  Deli / Bodega                          Sushi Restaurant
# 36               Sushi Restaurant                             Deli / Bodega
# 37                 Baseball Field                               Gas Station
# 38                           Café                               Yoga Studio
# 39                   Burger Joint                                       Bar
# 40                            Pub                                Restaurant
# 41             College Auditorium                                       Bar
# 42                           Café                 Middle Eastern Restaurant
# 43                      Gastropub                                Restaurant
# 44                   Neighborhood                               Yoga Studio
# 45                    Cheese Shop                                       Pub
# 46            Japanese Restaurant                            Sandwich Place
# 47                     Restaurant                                Baby Store
# 48                 Clothing Store                                     Hotel
# 49                  Grocery Store                                      Park
# 50                          Hotel                       Fried Chicken Joint
# 51                    Men's Store                                      Café
# 52                     Restaurant                            Ice Cream Shop
# 53                     Restaurant                               Salad Place
# 54                         Bakery                                Restaurant
# 55             Italian Restaurant                                 Pet Store
# 56                          Hotel                                       Gym
# 57                        Brewery                       American Restaurant
# 58                    Yoga Studio                                 Drugstore
# 59             English Restaurant                                Donut Shop
# 60              Food & Drink Shop                            Sandwich Place
# 61                  Jewelry Store                               Yoga Studio
# 62             Mexican Restaurant                                    Bakery
# 63             Salon / Barbershop                                Bagel Shop
# 64  Vegetarian / Vegan Restaurant                                Donut Shop
# 65             Italian Restaurant               Eastern European Restaurant
# 66             Italian Restaurant                               Coffee Shop
# 67                            Bar                        Italian Restaurant
# 68                            Pub                          Sushi Restaurant
# 69                    Yoga Studio                       Empanada Restaurant
# 70                         Bakery                        Mexican Restaurant
# 71            American Restaurant                                Bagel Shop
# 72                          Plane                                  Boutique
# 73                    Yoga Studio                       Empanada Restaurant
# 74                   Cocktail Bar                       Japanese Restaurant
# 75                     Restaurant                                      Café
# 76                            Gym                                     Hotel
# 77                        Gay Bar                                Restaurant
# 78               Recording Studio                                Restaurant
#
#      6th Most Common Venue          7th Most Common Venue  \
# 0               Steakhouse                  Shopping Mall
# 1       Salon / Barbershop                    Coffee Shop
# 2                      Gym             Mexican Restaurant
# 3            Deli / Bodega             Frozen Yogurt Shop
# 4              Yoga Studio           Caribbean Restaurant
# 5       Chinese Restaurant                           Park
# 6                      Bar             Seafood Restaurant
# 7                     Park                            Spa
# 8                      Spa              French Restaurant
# 9         Sushi Restaurant                      Wine Shop
# 10                    Café           Gym / Fitness Center
# 11              Restaurant                 Baseball Field
# 12             Coffee Shop            American Restaurant
# 13                 Theater            Indie Movie Theater
# 14                     Gym                Thai Restaurant
# 15        Cuban Restaurant                    Pizza Place
# 16     Japanese Restaurant                      Juice Bar
# 17                  Bakery                      Nightclub
# 18             Coffee Shop           Caribbean Restaurant
# 19               Juice Bar                       Wine Bar
# 20                Pharmacy                           Café
# 21             Coffee Shop                           Café
# 22          Ice Cream Shop                    Pizza Place
# 23          Ice Cream Shop             Salon / Barbershop
# 24             Coffee Shop                   Cocktail Bar
# 25           Grocery Store             Italian Restaurant
# 26            Burger Joint                 Sandwich Place
# 27         Thai Restaurant                     Playground
# 28                   Plaza                      Wine Shop
# 29              Steakhouse                      Juice Bar
# 30               Bookstore            Japanese Restaurant
# 31     Japanese Restaurant             Mexican Restaurant
# 32                    Park                            Spa
# 33               Hotel Bar                    Coffee Shop
# 34              Bagel Shop                            Gym
# 35                Wine Bar             Italian Restaurant
# 36      Seafood Restaurant                            Bar
# 37    Gym / Fitness Center                   Cocktail Bar
# 38     Japanese Restaurant  Vegetarian / Vegan Restaurant
# 39                     Gym                     Restaurant
# 40                 Theater                 Breakfast Spot
# 41                Beer Bar                   Burger Joint
# 42          Cosmetics Shop            Japanese Restaurant
# 43     American Restaurant                 Cosmetics Shop
# 44     Empanada Restaurant               Doner Restaurant
# 45                Beer Bar                     Restaurant
# 46            Burger Joint                Bubble Tea Shop
# 47             Candy Store                          Diner
# 48                     Gym                Thai Restaurant
# 49                    Café                    Music Venue
# 50     Sporting Goods Shop                 Scenic Lookout
# 51             Coffee Shop  Vegetarian / Vegan Restaurant
# 52  Furniture / Home Store           Caribbean Restaurant
# 53      Seafood Restaurant            Japanese Restaurant
# 54           Grocery Store                            Gym
# 55                     Pub                     Restaurant
# 56     American Restaurant             Seafood Restaurant
# 57                  Bakery                          Diner
# 58     Dumpling Restaurant                 Duty-free Shop
# 59               Drugstore            Dumpling Restaurant
# 60    Gym / Fitness Center                           Park
# 61      English Restaurant                     Donut Shop
# 62  Furniture / Home Store                          Diner
# 63      Mexican Restaurant                            Spa
# 64               BBQ Joint                   Liquor Store
# 65            Dessert Shop                    Coffee Shop
# 66                    Café               Sushi Restaurant
# 67              Restaurant                         Bakery
# 68             Pizza Place                    Fish Market
# 69        Doner Restaurant                     Donut Shop
# 70                     Bar                    Gaming Cafe
# 71      Light Rail Station                   Liquor Store
# 72        Sculpture Garden                    Coffee Shop
# 73        Doner Restaurant                     Donut Shop
# 74                Beer Bar                     Restaurant
# 75                     Pub             Chinese Restaurant
# 76              Restaurant                     Steakhouse
# 77             Yoga Studio       Mediterranean Restaurant
# 78                    Park                     Skate Park
#
#             8th Most Common Venue        9th Most Common Venue  \
# 0                 Supplement Shop           Seafood Restaurant
# 1                  Ice Cream Shop                 Optical Shop
# 2                     Supermarket               Sandwich Place
# 3              Chinese Restaurant         Caribbean Restaurant
# 4                Sushi Restaurant                       Bakery
# 5                     Bus Station                    BBQ Joint
# 6                          Market                    Juice Bar
# 7                  Sandwich Place                 Liquor Store
# 8                         Exhibit                  Yoga Studio
# 9                     Pizza Place          Japanese Restaurant
# 10                            Gym                 Burger Joint
# 11                 Sandwich Place               Scenic Lookout
# 12                      Bookstore            Indian Restaurant
# 13                      Wine Shop            French Restaurant
# 14            American Restaurant               Sandwich Place
# 15                 Clothing Store             Sushi Restaurant
# 16                           Café                Deli / Bodega
# 17             Italian Restaurant                 Cupcake Shop
# 18            Indie Movie Theater            Indian Restaurant
# 19                 Ice Cream Shop             Ramen Restaurant
# 20            Filipino Restaurant     Mediterranean Restaurant
# 21                            Spa                   Playground
# 22       Mediterranean Restaurant               Sandwich Place
# 23                    Pizza Place               Clothing Store
# 24                           Park          American Restaurant
# 25            Szechuan Restaurant                    Bike Shop
# 26             Seafood Restaurant                  Supermarket
# 27            American Restaurant           Italian Restaurant
# 28                  Boat or Ferry                 Gourmet Shop
# 29                   Cocktail Bar                  Event Space
# 30                            Gym                Grocery Store
# 31                      Bookstore             Sushi Restaurant
# 32                    Yoga Studio         Gym / Fitness Center
# 33            Japanese Restaurant         Gym / Fitness Center
# 34                  Grocery Store      Health & Beauty Service
# 35              French Restaurant           Seafood Restaurant
# 36                    Pizza Place              Thai Restaurant
# 37                Harbor / Marina                  Pet Service
# 38                            Spa                          Gym
# 39                           Park                  Coffee Shop
# 40                           Café               Chocolate Shop
# 41                  Smoothie Shop                Burrito Place
# 42             Italian Restaurant                      Theater
# 43                            Gym                      Theater
# 44                     Donut Shop                    Drugstore
# 45                         Bakery           Seafood Restaurant
# 46               Department Store                  Salad Place
# 47                      Nightclub           Italian Restaurant
# 48                  Deli / Bodega                    Bookstore
# 49                        Brewery    Middle Eastern Restaurant
# 50             Italian Restaurant                      Brewery
# 51                    Yoga Studio                      Theater
# 52                         Bakery           Frozen Yogurt Shop
# 53                  Deli / Bodega          American Restaurant
# 54                   Climbing Gym           Italian Restaurant
# 55                 Sandwich Place                Movie Theater
# 56             Italian Restaurant                Deli / Bodega
# 57                 Clothing Store                         Bank
# 58    Eastern European Restaurant          Egyptian Restaurant
# 59                 Duty-free Shop  Eastern European Restaurant
# 60               Department Store            Electronics Store
# 61                      Drugstore          Dumpling Restaurant
# 62      Cajun / Creole Restaurant                Grocery Store
# 63           Fast Food Restaurant                         Café
# 64                    Shoe Repair             Asian Restaurant
# 65                     Restaurant                          Bar
# 66                            Gym      New American Restaurant
# 67                   Dessert Shop                      Theater
# 68                      Bookstore            French Restaurant
# 69                      Drugstore          Dumpling Restaurant
# 70  Vegetarian / Vegan Restaurant                 Dessert Shop
# 71                     Restaurant             Sushi Restaurant
# 72                Harbor / Marina          Rental Car Location
# 73                      Drugstore          Dumpling Restaurant
# 74                            Pub           Seafood Restaurant
# 75             Italian Restaurant                    Pet Store
# 76            American Restaurant             Asian Restaurant
# 77                Bubble Tea Shop                   Smoke Shop
# 78                  Burrito Place               Farmers Market
#
#      10th Most Common Venue
# 0                Donut Shop
# 1       American Restaurant
# 2                      Bank
# 3       American Restaurant
# 4                    School
# 5       Fried Chicken Joint
# 6                 BBQ Joint
# 7                Taco Place
# 8                 Wine Shop
# 9        Mexican Restaurant
# 10          Thai Restaurant
# 11                   School
# 12       Seafood Restaurant
# 13      American Restaurant
# 14                      Spa
# 15                     Café
# 16               Steakhouse
# 17       Seafood Restaurant
# 18                      Bar
# 19      Filipino Restaurant
# 20             Tennis Court
# 21        French Restaurant
# 22          Thai Restaurant
# 23              Art Gallery
# 24                Jazz Club
# 25                      Spa
# 26            Grocery Store
# 27           Ice Cream Shop
# 28               Food Court
# 29                      Bar
# 30                      Pub
# 31                Wine Shop
# 32         Sushi Restaurant
# 33  New American Restaurant
# 34       Mexican Restaurant
# 35                   Garden
# 36                  Dog Run
# 37                 Fountain
# 38        Outdoor Sculpture
# 39                  Dog Run
# 40                     Bank
# 41                     Café
# 42                 Tea Room
# 43           Lingerie Store
# 44      Dumpling Restaurant
# 45           Breakfast Spot
# 46        Korean Restaurant
# 47              Coffee Shop
# 48         Sushi Restaurant
# 49              Supermarket
# 50               Restaurant
# 51      Japanese Restaurant
# 52                    Trail
# 53       Italian Restaurant
# 54    Performing Arts Venue
# 55            Burrito Place
# 56      Japanese Restaurant
# 57                      Bar
# 58        Electronics Store
# 59      Egyptian Restaurant
# 60               Donut Shop
# 61           Duty-free Shop
# 62      Fried Chicken Joint
# 63                    Diner
# 64                     Park
# 65         Cuban Restaurant
# 66       Seafood Restaurant
# 67                     Bank
# 68          Supplement Shop
# 69           Duty-free Shop
# 70            Grocery Store
# 71      Fried Chicken Joint
# 72            Boat or Ferry
# 73           Duty-free Shop
# 74              Cheese Shop
# 75               Playground
# 76       Seafood Restaurant
# 77             Burger Joint
# 78     Fast Food Restaurant

# %% [markdown]
# ## 5. Examine Clusters

# %% [markdown]
# Now, you can examine each cluster and determine the discriminating venue categories that distinguish each cluster. Based on the defining categories, you can then assign a name to each cluster. I will leave this exercise to you.

# %% [markdown]
# #### Cluster 1

# %%
Cluster1 = Final_merged.loc[Final_merged['Cluster Labels'] == 0, Final_merged.columns[[1] + list(range(5, Final_merged.shape[1]))]]

# %%
Cluster1
# Out:
#                                         Neighbourhood 1st Most Common Venue  \
# 11                                   Roosevelt Island                  Park
# 28                                  Battery Park City                  Park
# 37                                    Stuyvesant Town                  Park
# 55                     India Bazaar, The Beaches West                  Park
# 58                                      Lawrence Park              Bus Line
# 60                                   Davisville North                 Hotel
# 78  Business reply mail Processing Centre, South C...           Yoga Studio
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 11            Playground          Liquor Store   Japanese Restaurant
# 28           Coffee Shop                 Hotel                   Gym
# 37            Playground              Heliport        Baseball Field
# 55  Fast Food Restaurant     Fish & Chips Shop    Italian Restaurant
# 58                  Park           Swim School           Yoga Studio
# 60        Breakfast Spot           Pizza Place     Food & Drink Shop
# 78  Gym / Fitness Center            Comic Shop      Recording Studio
#
#                        5th Most Common Venue 6th Most Common Venue  \
# 11  Residential Building (Apartment / Condo)            Restaurant
# 28                             Memorial Site                 Plaza
# 37                               Gas Station  Gym / Fitness Center
# 55                                 Pet Store                   Pub
# 58                                 Drugstore   Dumpling Restaurant
# 60                            Sandwich Place  Gym / Fitness Center
# 78                                Restaurant                  Park
#
#    7th Most Common Venue        8th Most Common Venue 9th Most Common Venue  \
# 11        Baseball Field               Sandwich Place        Scenic Lookout
# 28             Wine Shop                Boat or Ferry          Gourmet Shop
# 37          Cocktail Bar              Harbor / Marina           Pet Service
# 55            Restaurant               Sandwich Place         Movie Theater
# 58        Duty-free Shop  Eastern European Restaurant   Egyptian Restaurant
# 60                  Park             Department Store     Electronics Store
# 78            Skate Park                Burrito Place        Farmers Market
#
#    10th Most Common Venue
# 11                 School
# 28             Food Court
# 37               Fountain
# 55          Burrito Place
# 58      Electronics Store
# 60             Donut Shop
# 78   Fast Food Restaurant

# %% [markdown]
# #### Cluster 2

# %%
Cluster2 = Final_merged.loc[Final_merged['Cluster Labels'] == 1, Final_merged.columns[[1] + list(range(5, Final_merged.shape[1]))]]

# %%
Cluster2
# Out:
#    Neighbourhood 1st Most Common Venue 2nd Most Common Venue  \
# 59      Roselawn          Home Service                Garden
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 59           Yoga Studio    English Restaurant            Donut Shop
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 59             Drugstore   Dumpling Restaurant        Duty-free Shop
#
#           9th Most Common Venue 10th Most Common Venue
# 59  Eastern European Restaurant    Egyptian Restaurant

# %% [markdown]
# #### Cluster 3

# %%
Cluster3 = Final_merged.loc[Final_merged['Cluster Labels'] == 2, Final_merged.columns[[1] + list(range(5, Final_merged.shape[1]))]]

# %%
Cluster3
# Out:
#    Neighbourhood 1st Most Common Venue 2nd Most Common Venue  \
# 44   The Beaches                   Pub                 Trail
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 44     Health Food Store          Neighborhood           Yoga Studio
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 44   Empanada Restaurant      Doner Restaurant            Donut Shop
#
#    9th Most Common Venue 10th Most Common Venue
# 44             Drugstore    Dumpling Restaurant

# %% [markdown]
# #### Cluster 4

# %%
Cluster4 = Final_merged.loc[Final_merged['Cluster Labels'] == 3, Final_merged.columns[[1] + list(range(5, Final_merged.shape[1]))]]

# %%
Cluster4
# Out:
#                                         Neighbourhood 1st Most Common Venue  \
# 0                                         Marble Hill        Sandwich Place
# 1                                           Chinatown    Chinese Restaurant
# 2                                  Washington Heights                  Café
# 3                                              Inwood    Mexican Restaurant
# 4                                    Hamilton Heights           Pizza Place
# 5                                      Manhattanville           Coffee Shop
# 6                                      Central Harlem    African Restaurant
# 7                                         East Harlem    Mexican Restaurant
# 8                                     Upper East Side    Italian Restaurant
# 9                                           Yorkville           Coffee Shop
# 10                                         Lenox Hill           Coffee Shop
# 12                                    Upper West Side                   Bar
# 13                                     Lincoln Square                 Plaza
# 14                                            Clinton               Theater
# 15                                            Midtown           Coffee Shop
# 16                                        Murray Hill        Sandwich Place
# 17                                            Chelsea           Art Gallery
# 18                                  Greenwich Village    Italian Restaurant
# 19                                       East Village          Cocktail Bar
# 20                                    Lower East Side    Chinese Restaurant
# 21                                            Tribeca    Italian Restaurant
# 22                                       Little Italy    Chinese Restaurant
# 23                                               Soho    Italian Restaurant
# 24                                       West Village    Italian Restaurant
# 25                                   Manhattan Valley           Coffee Shop
# 26                                Morningside Heights                  Park
# 27                                           Gramercy            Bagel Shop
# 29                                 Financial District           Coffee Shop
# 30                                      Carnegie Hill           Coffee Shop
# 31                                               Noho           Coffee Shop
# 32                                       Civic Center           Coffee Shop
# 33                                      Midtown South     Korean Restaurant
# 34                                       Sutton Place           Coffee Shop
# 35                                         Turtle Bay           Coffee Shop
# 45              Cocktail Bar                      Café
# 46        Italian Restaurant                      Café
# 47                      Café                      Park
# 48                      Café                Restaurant
# 49                    Bakery                      Pool
# 50                  Aquarium                      Café
# 51          Asian Restaurant                Restaurant
# 52        Italian Restaurant               Coffee Shop
# 53                     Hotel                      Café
# 54               Coffee Shop            Breakfast Spot
# 56                      Café                Restaurant
# 57               Coffee Shop                 Gastropub
# 61          Sushi Restaurant                     Trail
# 62                      Park           Thai Restaurant
# 63            Clothing Store               Yoga Studio
# 64                      Café               Coffee Shop
# 65            Breakfast Spot                   Dog Run
# 66            Sandwich Place              Dessert Shop
# 67                 Bookstore       Japanese Restaurant
# 68                      Café        Italian Restaurant
# 70               Coffee Shop     Vietnamese Restaurant
# 71                       Pub               Pizza Place
# 72            Airport Lounge          Airport Terminal
# 74                      Café        Italian Restaurant
# 75                    Bakery               Pizza Place
# 76                      Café       Japanese Restaurant
# 77          Sushi Restaurant       Japanese Restaurant
#
#             4th Most Common Venue        5th Most Common Venue  \
# 0                     Yoga Studio           Miscellaneous Shop
# 1                 Bubble Tea Shop        Vietnamese Restaurant
# 2              Chinese Restaurant            Mobile Phone Shop
# 3                            Café                       Bakery
# 4              Mexican Restaurant                Deli / Bodega
# 5              Italian Restaurant           Mexican Restaurant
# 6              Chinese Restaurant            French Restaurant
# 7                   Deli / Bodega    Latin American Restaurant
# 8                     Coffee Shop                    Juice Bar
# 9                             Bar                Deli / Bodega
# 10               Sushi Restaurant                 Cocktail Bar
# 12                       Wine Bar                 Dessert Shop
# 13          Performing Arts Venue                 Concert Hall
# 14                          Hotel           Italian Restaurant
# 15                        Theater          Japanese Restaurant
# 16                    Coffee Shop                        Hotel
# 17            American Restaurant               Ice Cream Shop
# 18                    Pizza Place                          Gym
# 19                            Bar                  Coffee Shop
# 20                   Cocktail Bar                       Bakery
# 21                         Bakery                     Wine Bar
# 22                Bubble Tea Shop                       Bakery
# 23                    Coffee Shop                       Bakery
# 24        New American Restaurant                       Bakery
# 25                    Pizza Place                          Bar
# 26                    Coffee Shop                Deli / Bodega
# 27                            Bar           Mexican Restaurant
# 29                           Café                        Hotel
# 30                    Yoga Studio                    Wine Shop
# 31                 Sandwich Place                Grocery Store
# 32                   Cocktail Bar                        Hotel
# 33                   Dessert Shop                 Burger Joint
# 34           Gym / Fitness Center                        Hotel
# 35                  Deli / Bodega             Sushi Restaurant
# 36               Sushi Restaurant                Deli / Bodega
# 38                           Café                  Yoga Studio
# 39                   Burger Joint                          Bar
# 40                            Pub                   Restaurant
# 41             College Auditorium                          Bar
# 42                           Café    Middle Eastern Restaurant
# 43                      Gastropub                   Restaurant
# 45                    Cheese Shop                          Pub
# 46            Japanese Restaurant               Sandwich Place
# 47                     Restaurant                   Baby Store
# 48                 Clothing Store                        Hotel
# 49                  Grocery Store                         Park
# 50                          Hotel          Fried Chicken Joint
# 51                    Men's Store                         Café
# 52                     Restaurant               Ice Cream Shop
# 53                     Restaurant                  Salad Place
# 54                         Bakery                   Restaurant
# 56                          Hotel                          Gym
# 57                        Brewery          American Restaurant
# 61                  Jewelry Store                  Yoga Studio
# 62             Mexican Restaurant                       Bakery
# 63             Salon / Barbershop                   Bagel Shop
# 64  Vegetarian / Vegan Restaurant                   Donut Shop
# 65             Italian Restaurant  Eastern European Restaurant
# 66             Italian Restaurant                  Coffee Shop
# 67                            Bar           Italian Restaurant
# 68                            Pub             Sushi Restaurant
# 70                         Bakery           Mexican Restaurant
# 71            American Restaurant                   Bagel Shop
# 72                          Plane                     Boutique
# 74                   Cocktail Bar          Japanese Restaurant
# 75                     Restaurant                         Café
# 76                            Gym                        Hotel
# 77                        Gay Bar                   Restaurant
#
#      6th Most Common Venue          7th Most Common Venue  \
# 0               Steakhouse                  Shopping Mall
# 1       Salon / Barbershop                    Coffee Shop
# 2                      Gym             Mexican Restaurant
# 3            Deli / Bodega             Frozen Yogurt Shop
# 4              Yoga Studio           Caribbean Restaurant
# 5       Chinese Restaurant                           Park
# 6                      Bar             Seafood Restaurant
# 7                     Park                            Spa
# 8                      Spa              French Restaurant
# 9         Sushi Restaurant                      Wine Shop
# 10                    Café           Gym / Fitness Center
# 12             Coffee Shop            American Restaurant
# 13                 Theater            Indie Movie Theater
# 14                     Gym                Thai Restaurant
# 15        Cuban Restaurant                    Pizza Place
# 16     Japanese Restaurant                      Juice Bar
# 17                  Bakery                      Nightclub
# 18             Coffee Shop           Caribbean Restaurant
# 19               Juice Bar                       Wine Bar
# 20                Pharmacy                           Café
# 21             Coffee Shop                           Café
# 22          Ice Cream Shop                    Pizza Place
# 23          Ice Cream Shop             Salon / Barbershop
# 24             Coffee Shop                   Cocktail Bar
# 25           Grocery Store             Italian Restaurant
# 26            Burger Joint                 Sandwich Place
# 27         Thai Restaurant                     Playground
# 29              Steakhouse                      Juice Bar
# 30               Bookstore            Japanese Restaurant
# 31     Japanese Restaurant             Mexican Restaurant
# 32                    Park                            Spa
# 33               Hotel Bar                    Coffee Shop
# 34              Bagel Shop                            Gym
# 35                Wine Bar             Italian Restaurant
# 36      Seafood Restaurant                            Bar
# 38     Japanese Restaurant  Vegetarian / Vegan Restaurant
# 39                     Gym                     Restaurant
# 40                 Theater                 Breakfast Spot
# 41                Beer Bar                   Burger Joint
# 42          Cosmetics Shop            Japanese Restaurant
# 43     American Restaurant                 Cosmetics Shop
# 45                Beer Bar                     Restaurant
# 46            Burger Joint                Bubble Tea Shop
# 47             Candy Store                          Diner
# 48                     Gym                Thai Restaurant
# 49                    Café                    Music Venue
# 50     Sporting Goods Shop                 Scenic Lookout
# 51             Coffee Shop  Vegetarian / Vegan Restaurant
# 52  Furniture / Home Store           Caribbean Restaurant
# 53      Seafood Restaurant            Japanese Restaurant
# 54           Grocery Store                            Gym
# 56     American Restaurant             Seafood Restaurant
# 57                  Bakery                          Diner
# 61      English Restaurant                     Donut Shop
# 62  Furniture / Home Store                          Diner
# 63      Mexican Restaurant                            Spa
# 64               BBQ Joint                   Liquor Store
# 65            Dessert Shop                    Coffee Shop
# 66                    Café               Sushi Restaurant
# 67              Restaurant                         Bakery
# 68             Pizza Place                    Fish Market
# 70                     Bar                    Gaming Cafe
# 71      Light Rail Station                   Liquor Store
# 72        Sculpture Garden                    Coffee Shop
# 74                Beer Bar                     Restaurant
# 75                     Pub             Chinese Restaurant
# 76              Restaurant                     Steakhouse
# 77             Yoga Studio       Mediterranean Restaurant
#
#             8th Most Common Venue      9th Most Common Venue  \
# 0                 Supplement Shop         Seafood Restaurant
# 1                  Ice Cream Shop               Optical Shop
# 2                     Supermarket             Sandwich Place
# 3              Chinese Restaurant       Caribbean Restaurant
# 4                Sushi Restaurant                     Bakery
# 5                     Bus Station                  BBQ Joint
# 6                          Market                  Juice Bar
# 7                  Sandwich Place               Liquor Store
# 8                         Exhibit                Yoga Studio
# 9                     Pizza Place        Japanese Restaurant
# 10                            Gym               Burger Joint
# 12                      Bookstore          Indian Restaurant
# 13                      Wine Shop          French Restaurant
# 14            American Restaurant             Sandwich Place
# 15                 Clothing Store           Sushi Restaurant
# 16                           Café              Deli / Bodega
# 17             Italian Restaurant               Cupcake Shop
# 18            Indie Movie Theater          Indian Restaurant
# 19                 Ice Cream Shop           Ramen Restaurant
# 20            Filipino Restaurant   Mediterranean Restaurant
# 21                            Spa                 Playground
# 22       Mediterranean Restaurant             Sandwich Place
# 23                    Pizza Place             Clothing Store
# 24                           Park        American Restaurant
# 25            Szechuan Restaurant                  Bike Shop
# 26             Seafood Restaurant                Supermarket
# 27            American Restaurant         Italian Restaurant
# 29                   Cocktail Bar                Event Space
# 30                            Gym              Grocery Store
# 31                      Bookstore           Sushi Restaurant
# 32                    Yoga Studio       Gym / Fitness Center
# 33            Japanese Restaurant       Gym / Fitness Center
# 34                  Grocery Store    Health & Beauty Service
# 35              French Restaurant         Seafood Restaurant
# 36                    Pizza Place            Thai Restaurant
# 38                            Spa                        Gym
# 39                           Park                Coffee Shop
# 40                           Café             Chocolate Shop
# 41                  Smoothie Shop              Burrito Place
# 42             Italian Restaurant                    Theater
# 43                            Gym                    Theater
# 45                         Bakery         Seafood Restaurant
# 46               Department Store                Salad Place
# 47                      Nightclub         Italian Restaurant
# 48                  Deli / Bodega                  Bookstore
# 49                        Brewery  Middle Eastern Restaurant
# 50             Italian Restaurant                    Brewery
# 51                    Yoga Studio                    Theater
# 52                         Bakery         Frozen Yogurt Shop
# 53                  Deli / Bodega        American Restaurant
# 54                   Climbing Gym         Italian Restaurant
# 56             Italian Restaurant              Deli / Bodega
# 57                 Clothing Store                       Bank
# 61                      Drugstore        Dumpling Restaurant
# 62      Cajun / Creole Restaurant              Grocery Store
# 63           Fast Food Restaurant                       Café
# 64                    Shoe Repair           Asian Restaurant
# 65                     Restaurant                        Bar
# 66                            Gym    New American Restaurant
# 67                   Dessert Shop                    Theater
# 68                      Bookstore          French Restaurant
# 70  Vegetarian / Vegan Restaurant               Dessert Shop
# 71                     Restaurant           Sushi Restaurant
# 72                Harbor / Marina        Rental Car Location
# 74                            Pub         Seafood Restaurant
# 75             Italian Restaurant                  Pet Store
# 76            American Restaurant           Asian Restaurant
# 77                Bubble Tea Shop                 Smoke Shop
#
#      10th Most Common Venue
# 0                Donut Shop
# 1       American Restaurant
# 2                      Bank
# 3       American Restaurant
# 4                    School
# 5       Fried Chicken Joint
# 6                 BBQ Joint
# 7                Taco Place
# 8                 Wine Shop
# 9        Mexican Restaurant
# 10          Thai Restaurant
# 12       Seafood Restaurant
# 13      American Restaurant
# 14                      Spa
# 15                     Café
# 16               Steakhouse
# 17       Seafood Restaurant
# 18                      Bar
# 19      Filipino Restaurant
# 20             Tennis Court
# 21        French Restaurant
# 22          Thai Restaurant
# 23              Art Gallery
# 24                Jazz Club
# 25                      Spa
# 26            Grocery Store
# 27           Ice Cream Shop
# 29                      Bar
# 30                      Pub
# 31                Wine Shop
# 32         Sushi Restaurant
# 33  New American Restaurant
# 34       Mexican Restaurant
# 35                   Garden
# 36                  Dog Run
# 38        Outdoor Sculpture
# 39                  Dog Run
# 40                     Bank
# 41                     Café
# 42                 Tea Room
# 43           Lingerie Store
# 45           Breakfast Spot
# 46        Korean Restaurant
# 47              Coffee Shop
# 48         Sushi Restaurant
# 49              Supermarket
# 50               Restaurant
# 51      Japanese Restaurant
# 52                    Trail
# 53       Italian Restaurant
# 54    Performing Arts Venue
# 56      Japanese Restaurant
# 57                      Bar
# 61           Duty-free Shop
# 62      Fried Chicken Joint
# 63                    Diner
# 64                     Park
# 65         Cuban Restaurant
# 66       Seafood Restaurant
# 67                     Bank
# 68          Supplement Shop
# 70            Grocery Store
# 71      Fried Chicken Joint
# 72            Boat or Ferry
# 74              Cheese Shop
# 75               Playground
# 76       Seafood Restaurant
# 77             Burger Joint

# %% [markdown]
# #### Cluster 5

# %%
Cluster5 = Final_merged.loc[Final_merged['Cluster Labels'] == 4, Final_merged.columns[[1] + list(range(5, Final_merged.shape[1]))]]

# %%
Cluster5
# Out:
#                   Neighbourhood 1st Most Common Venue 2nd Most Common Venue  \
# 69  Moore Park, Summerhill East                  Park                 Trail
# 73                     Rosedale                  Park            Playground
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 69            Restaurant           Yoga Studio   Empanada Restaurant
# 73                 Trail           Yoga Studio   Empanada Restaurant
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 69      Doner Restaurant            Donut Shop             Drugstore
# 73      Doner Restaurant            Donut Shop             Drugstore
#
#    9th Most Common Venue 10th Most Common Venue
# 69   Dumpling Restaurant         Duty-free Shop
# 73   Dumpling Restaurant         Duty-free Shop

# %%
area = input("Enter your current area: ")

if Cluster5[Cluster5['Neighbourhood'].str.contains(area, case = False, regex = False)].shape > (0,11):
    print("Correct")
else:
    print("Not")
# Out:
# Enter your current area:  rose
# Correct

# %%
area = input("Enter your current area: ")

if Cluster1[Cluster1['Neighbourhood'].str.contains(area, case = False, regex = False)].shape > (0,11):
    print("Cluster1")
    
elif Cluster2[Cluster2['Neighbourhood'].str.contains(area, case = False, regex = False)].shape > (0,11):
    print("Cluster2")

elif Cluster3[Cluster3['Neighbourhood'].str.contains(area, case = False, regex = False)].shape > (0,11):
    print("Cluster3")
    
elif Cluster4[Cluster4['Neighbourhood'].str.contains(area, case = False, regex = False)].shape > (0,11):
    print("Cluster4")

elif Cluster5[Cluster5['Neighbourhood'].str.contains(area, case = False, regex = False)].shape > (0,11):
    print("Cluster5")
    
else:
    print("Area not found in any cluster.")
# Out:
# Enter your current area:  lawrence
# Cluster1
